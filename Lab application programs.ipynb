# %%
#Inventory
def show():
    for i in h:
        print(i,"\t")
  
def checkInven():
  for i in range(1,len(h)):
    if(h[i][3]<=5):
      print("\nStock filled")
      h[i][3]=20

h=[['S.No','Name','Price','Quantity', 'Manufacturer'],[1,'Mouse',500,20,'Dell'],[2,'Keyboard',1000,15,'HP'],[3,'Monitor',2500,10,'Samsung'],[4,'Pendrive',1000,25,'Transcend']]
n=5
cost=0
while(n!=0):
  checkInven()
  print("\nInventory is\n")
  show()
  n=int(input("\n1:Purchase\n2:Count\n0:exit\n"))
  if(n==1):
    a=int(input("Enter the S.No "))
    if(a>4):
      print("Incorrect option. Try again.")
      continue
    count=int(input("Number of units required: "))
    if(h[a][3]<count):
      print("Sorry.. not enough stock")
    else:
      h[a][3]-=count
      print("Item Added ")
      cost+=h[a][2]*count
  elif(n==2):
    b=int(input("Enter the S.No "))
    if(b>4):
      print("Incorrect option. Try again.")
      continue
    print("Remaining Stock: ",h[b][3])
  elif(n==0):
    pass
  else:
    print("Incorrect option. Try again.")
print("\nTotal bill amount: ",cost,"\nThank you!")
# Out:
# Inventory is
#
# ['S.No', 'Name', 'Price', 'Quantity', 'Manufacturer']
# [1, 'Mouse', 500, 20, 'Dell']
# [2, 'Keyboard', 1000, 15, 'HP']
# [3, 'Monitor', 2500, 10, 'Samsung']
# [4, 'Pendrive', 1000, 25, 'Transcend']
#
# 1:Purchase
# 2:Count
# 0:exit
# 1
# Enter the S.No 3
# Number of units required: 5
# Item Added
#
# Stock filled
#
# Inventory is
#
# ['S.No', 'Name', 'Price', 'Quantity', 'Manufacturer']
# [1, 'Mouse', 500, 20, 'Dell']
# [2, 'Keyboard', 1000, 15, 'HP']
# [3, 'Monitor', 2500, 20, 'Samsung']
# [4, 'Pendrive', 1000, 25, 'Transcend']
#
# 1:Purchase
# 2:Count
# 0:exit
# 2
# Enter the S.No 3
# Remaining Stock:  20
#
# Inventory is
#
# ['S.No', 'Name', 'Price', 'Quantity', 'Manufacturer']
# [1, 'Mouse', 500, 20, 'Dell']
# [2, 'Keyboard', 1000, 15, 'HP']
# [3, 'Monitor', 2500, 20, 'Samsung']
# [4, 'Pendrive', 1000, 25, 'Transcend']
#
# 1:Purchase
# 2:Count
# 0:exit
# 0
#
# Total bill amount:  12500
# Thank you!

# %%
#Recharge
a=0
n=int(input("Please enter mobile number: "))
print("1.Airtel\n2.Jio\n3.VI\n4.BSNL")
o=int(input("Enter operator: "))
while(o!=0 and o<=4):
    print("\n1.Recharge\n2.Data\n3.Validity Extension\n4.Exit")
    c=int(input("Enter choice: "))
    if(c==1):
        r=int(input("Enter recharge amount: "))
        print("Recharge for Rs",r,"done successfully")
        a+=r
    elif(c==2):
        print("DataPlans\n1.2gb/d for 28 days=Rs 150\n2.1.5gb/d for 28 days=Rs120")
        d=int(input("Enter plan: "))
        if (d==1):
            print("Rs.150 data plan recharge successfull")
            a+=150
        elif(d==2):
            print("Rs.120 data plan recharge successfull")
            a+=120
        else:
            print("Wrong choice. Try again.")
            #continue
    elif(c==3):
        print("1.3 months for 120\n2.6 months for 250\n3.1 year for 495")
        v=int(input("Choose plan: "))
        if(v==1):
            print("3 months validity extended")
            a+=120
        elif(v==2):
            print("6 months validity extended")
            a+=250
        else:
            print("Wrong choice. Try again.")
    elif(c==4):
        print("Total bill amount:",a,"\nThank You!")
        break
    else:
        print("Wrong Choice. Try again")
# Out:
# Please enter mobile number: 9876543210
# 1.Airtel
# 2.Jio
# 3.VI
# 4.BSNL
# Enter operator: 2
#
# 1.Recharge
# 2.Data
# 3.Validity Extension
# 4.Exit
# Enter choice: 1
# Enter recharge amount: 86
# Recharge for Rs 86 done successfully
#
# 1.Recharge
# 2.Data
# 3.Validity Extension
# 4.Exit
# Enter choice: 2
# DataPlans
# 1.2gb/d for 28 days=Rs 150
# 2.1.5gb/d for 28 days=Rs120
# Enter plan: 3
# Wrong choice. Try again.
#
# 1.Recharge
# 2.Data
# 3.Validity Extension
# 4.Exit
# Enter choice: 2
# DataPlans
# 1.2gb/d for 28 days=Rs 150
# 2.1.5gb/d for 28 days=Rs120
# Enter plan: 1
# Rs.150 data plan recharge successfull
#
# 1.Recharge
# 2.Data
# 3.Validity Extension
# 4.Exit
# Enter choice: 3
# 1.3 months for 120
# 2.6 months for 250
# 3.1 year for 495
# Choose plan: 2
# 6 months validity extended
#
# 1.Recharge
# 2.Data
# 3.Validity Extension
# 4.Exit
# Enter choice: 4
# Total bill amount: 486
# Thank You!

# %%
#Food delivery
dp=['Zomato','Swiggy','Uber Eats']
fo=['Burger','Pizza','Rolls']
ba=[120,200,100]
c='y'
while(c!='n'):
  d=int(input("1.Swiggy\n2.Zomato\n3.Uber Eats\nChoose your delivery partner: "))
  f=int(input("\n1.Burger : 120/-\n2.Pizza : 200/-\n3.Rolls : 100/-\nEnter your choice "))
  a=input("\nEnter your address ")
  print("\nYour order for",fo[f-1],"has been placed on",dp[d-1],"and will arrive at your address",a,"\nBill Amount: ",ba[f-1])
  c=input("Do you wish to order again? (y/n)\n")
# Out:
# 1.Swiggy
# 2.Zomato
# 3.Uber Eats
# Choose your delivery partner: 1
#
# 1.Burger : 120/-
# 2.Pizza : 200/-
# 3.Rolls : 100/-
# Enter your choice 3
#
# Enter your address m
#
# Your order for Rolls has been placed on Zomato and will arrive at your address m
# Bill Amount:  100
# Do you wish to order again? (y/n)
# y
# 1.Swiggy
# 2.Zomato
# 3.Uber Eats
# Choose your delivery partner: 2
#
# 1.Burger : 120/-
# 2.Pizza : 200/-
# 3.Rolls : 100/-
# Enter your choice 3
#
# Enter your address l
#
# Your order for Rolls has been placed on Swiggy and will arrive at your address l
# Bill Amount:  100
# Do you wish to order again? (y/n)
# n

# %%
#landlord tentant
utilities=input("Enter all bills to be shared separated by space\n")
l1=utilities.split(" ")
l2=[]
a=0
n=int(input("Enter no. of tenants "))
n+=1
for i in range(len(l1)):
  print("Enter total amount for ",l1[i],"bill ")
  l2.append(float(input()))
for i in range(len(l1)):
  a+=round(l2[i]/n,2)
  print("The",l1[i],"bill is split as",round(l2[i]/n,2),"per head")
print("\nThe total per head is",a)
# Out:
# Enter all bills to be shared separated by space
# A B C
# Enter no. of tenants 2
# Enter total amount for  A bill
# 250
# Enter total amount for  B bill
# 552
# Enter total amount for  C bill
# 335
# The A bill is split as 83.33 per head
# The B bill is split as 184.0 per head
# The C bill is split as 111.67 per head
#
# The total per head is 379.0
